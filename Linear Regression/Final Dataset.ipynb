# %%
import pandas as pd

# %%
url1 ="https://raw.githubusercontent.com/polinaprinii/DAP-Project/main/Cases_and_Death_Rates/Data/Data%20for%20Multiple%20Linear%20Regression/Global_and_US_Confirmed_Cases_And_Deaths.csv?token=ASV4RS6WZYFUWQ325ZCQI3TBXDRT6"
cases_deaths =pd.read_csv(url1)

url2 = "https://raw.githubusercontent.com/polinaprinii/DAP-Project/main/Restriction%20and%20Testing%20Analysis/Restrictions/restrictions.csv?token=ASV4RS2EE7HC7DMD6OFAR4DBW6TQ6"
restrictions = pd.read_csv(url2)

url3 = "https://raw.githubusercontent.com/polinaprinii/DAP-Project/main/Restriction%20and%20Testing%20Analysis/world%20testing/testing.csv?token=ASV4RS424SAEGIM3KBA7P23BW6TTM"
tests = pd.read_csv(url3)

url4 = "https://raw.githubusercontent.com/polinaprinii/DAP-Project/main/Vaccine_Analysis_by_Country/Main%20Project/CSV%20Files/finalexport.csv?token=ASV4RSZSY4LEVQIIVPRB43LBW6WDI"
vaccine = pd.read_csv(url4)

# %%
merge1 = pd.merge(restrictions, tests, how="outer", left_on =["isocode","country"], right_on = ["isocode","country"])
merge1 = merge1[['isocode','country','MaxStringencyIndex','MeanStringencyIndex','MaxFacialCoverings','MeanFacialCoverings','MaxStayHome','MeanStayHome','tests']]
merge1
# Out:
#       isocode              country  MaxStringencyIndex  MeanStringencyIndex  \
# 0         AFG          Afghanistan               56.02            30.132369
# 1         ALB              Albania               63.89            49.158252
# 2         DZA              Algeria               85.19            60.175902
# 3         AND              Andorra               65.74            50.570954
# 4         AGO               Angola               65.74            56.662515
# ..        ...                  ...                 ...                  ...
# 255       TUV               Tuvalu                 NaN                  NaN
# 256  OWID_UMC  Upper middle income                 NaN                  NaN
# 257       VAT              Vatican                 NaN                  NaN
# 258       WLF    Wallis and Futuna                 NaN                  NaN
# 259  OWID_WRL                World                 NaN                  NaN
#
# ...

# %%
merge2 = pd.merge(merge1,cases_deaths,how="outer", left_on =["isocode","country"], right_on = ["isocode","country"])
merge2 = merge2[['isocode','MaxStringencyIndex','MeanStringencyIndex','MaxFacialCoverings','MeanFacialCoverings','MaxStayHome','MeanStayHome','tests','country','Confirmed','Deaths']]
merge2
# Out:
#     isocode  MaxStringencyIndex  MeanStringencyIndex  MaxFacialCoverings  \
# 0       AFG               56.02            30.132369                 3.0
# 1       ALB               63.89            49.158252                 4.0
# 2       DZA               85.19            60.175902                 3.0
# 3       AND               65.74            50.570954                 3.0
# 4       AGO               65.74            56.662515                 4.0
# ..      ...                 ...                  ...                 ...
# 267     SRB                 NaN                  NaN                 NaN
# 268     TLS                 NaN                  NaN                 NaN
# 269     USA                 NaN                  NaN                 NaN
# 270     VAT                 NaN                  NaN                 NaN
# 271     VIR                 NaN                  NaN                 NaN
#
#      MeanFacialCoverings  MaxStayHome  MeanStayHome       tests      country  \
# ...

# %%
merge3 = pd.merge(merge2, vaccine, how="outer", left_on =["isocode","country"], right_on = ["isocode","country"])
merge3
# Out:
#       isocode  MaxStringencyIndex  MeanStringencyIndex  MaxFacialCoverings  \
# 0         AFG               56.02            30.132369                 3.0
# 1         ALB               63.89            49.158252                 4.0
# 2         DZA               85.19            60.175902                 3.0
# 3         AND               65.74            50.570954                 3.0
# 4         AGO               65.74            56.662515                 4.0
# ..        ...                 ...                  ...                 ...
# 271       VIR                 NaN                  NaN                 NaN
# 272  OWID_ENG                 NaN                  NaN                 NaN
# 273  OWID_SCT                 NaN                  NaN                 NaN
# 274  OWID_WLS                 NaN                  NaN                 NaN
# 275  OWID_NIR                 NaN                  NaN                 NaN
#
#      MeanFacialCoverings  MaxStayHome  MeanStayHome       tests  \
# ...

# %%
merge3 = merge3[['isocode','MaxStringencyIndex','MeanStringencyIndex','MaxFacialCoverings','MeanFacialCoverings','MaxStayHome','MeanStayHome','tests','country','Confirmed','Deaths']]
merge3
# Out:
#       isocode  MaxStringencyIndex  MeanStringencyIndex  MaxFacialCoverings  \
# 0         AFG               56.02            30.132369                 3.0
# 1         ALB               63.89            49.158252                 4.0
# 2         DZA               85.19            60.175902                 3.0
# 3         AND               65.74            50.570954                 3.0
# 4         AGO               65.74            56.662515                 4.0
# ..        ...                 ...                  ...                 ...
# 271       VIR                 NaN                  NaN                 NaN
# 272  OWID_ENG                 NaN                  NaN                 NaN
# 273  OWID_SCT                 NaN                  NaN                 NaN
# 274  OWID_WLS                 NaN                  NaN                 NaN
# 275  OWID_NIR                 NaN                  NaN                 NaN
#
#      MeanFacialCoverings  MaxStayHome  MeanStayHome       tests  \
# ...

# %%
finalmerge = merge3[['isocode','country','Confirmed','Deaths','tests','MaxStringencyIndex','MeanStringencyIndex','MaxFacialCoverings','MeanFacialCoverings','MaxStayHome','MeanStayHome']]
finalmerge = pd.merge(finalmerge, vaccine,how="outer", left_on =["isocode","country"], right_on = ["isocode","country"])
finalmerge = finalmerge[['isocode','country','Confirmed','Deaths','tests','MaxStringencyIndex','MeanStringencyIndex','MaxFacialCoverings','MeanFacialCoverings','MaxStayHome','MeanStayHome','totalvaccinations','totalbooster','fullyvaccinated']]
finalmerge
# Out:
#       isocode           country  Confirmed  Deaths       tests  \
# 0         AFG       Afghanistan   157032.0  7306.0         0.0
# 1         ALB           Albania   197776.0  3063.0  81840662.0
# 2         DZA           Algeria   209463.0  6035.0         0.0
# 3         AND           Andorra    16426.0   131.0   8830188.0
# 4         AGO            Angola    65080.0  1731.0         0.0
# ..        ...               ...        ...     ...         ...
# 271       VIR                US     7490.0    85.0         NaN
# 272  OWID_ENG           England        NaN     NaN         NaN
# 273  OWID_SCT          Scotland        NaN     NaN         NaN
# 274  OWID_WLS             Wales        NaN     NaN         NaN
# 275  OWID_NIR  Northern Ireland        NaN     NaN         NaN
#
#      MaxStringencyIndex  MeanStringencyIndex  MaxFacialCoverings  \
# 0                 56.02            30.132369                 3.0
# 1                 63.89            49.158252                 4.0
# ...

# %%
finalmerge = finalmerge.drop(labels = range(187,276),axis = 0)
finalmerge
# Out:
#     isocode      country  Confirmed  Deaths        tests  MaxStringencyIndex  \
# 0       AFG  Afghanistan   157032.0  7306.0          0.0               56.02
# 1       ALB      Albania   197776.0  3063.0   81840662.0               63.89
# 2       DZA      Algeria   209463.0  6035.0          0.0               85.19
# 3       AND      Andorra    16426.0   131.0    8830188.0               65.74
# 4       AGO       Angola    65080.0  1731.0          0.0               65.74
# ..      ...          ...        ...     ...          ...                 ...
# 182     YEM        Yemen     9972.0  1942.0          0.0               37.96
# 183     ZMB       Zambia   210099.0  3667.0  559230229.0               60.19
# 184     ZWE     Zimbabwe   133747.0  4703.0  246350739.0               87.96
# 185     AFG          NaN        NaN     NaN          NaN                 NaN
# 186     AND          NaN        NaN     NaN          NaN                 NaN
#
# ...

# %%
finalmerge.to_csv('D:/Git/DAP-Project/Linear Regression/finaldataset.csv',encoding = 'utf-8')
